# %% [markdown]
# # Distributed MNIST with MLX and Kubeflow Trainer
#
# This Notebook will show how to run distributed MLX on Kubernetes with Kubeflow Trainer.
#
# The MLX runtime uses `mlx[cuda]` package to run distributed training on GPUs.
#
# MLX Distributed: https://ml-explore.github.io/mlx/build/html/usage/distributed.html

# %% [markdown]
# ## Install the Kubeflow SDK
#
# You need to install the Kubeflow SDK to interact with Kubeflow Trainer APIs:

# %%
# !pip install git+https://github.com/kubeflow/sdk.git@main

# %% [markdown]
# ## Install the MLX Dependencies
#
# You also need to install MLX packages to evaluate the trained model.

# %%
# !pip install "mlx>=0.28.0"
# !pip install "mlx-data>=0.1.0"
# !pip install "matplotlib>=3.10.5"

# %% [markdown]
# ## Update the GPU Resources
#
# Currently, Kubeflow Trainer does not support configuring MLX resources directly through a
# TrainJob specification.
#
# To adjust GPU allocations (and other container resource settings), you must manually patch the ClusterTrainingRuntime.
#
# Progress for native resource configuration in TrainJob is being tracked here: [kubeflow/trainer#2650](https://github.com/kubeflow/trainer/issues/2650)

# %%
patch = """
[
  {
    "op": "add",
    "path": "/spec/template/spec/replicatedJobs/0/template/spec/template/spec/containers/0/resources",
    "value": { "limits": { "nvidia.com/gpu": "1" } }
  },
  {
    "op": "add",
    "path": "/spec/template/spec/replicatedJobs/1/template/spec/template/spec/containers/0/resources",
    "value": { "limits": { "nvidia.com/gpu": "1" } }
  }
]
"""
# !kubectl patch clustertrainingruntime mlx-distributed --type='json' -p "$patch"
# Out:
# clustertrainingruntime.trainer.kubeflow.org/mlx-distributed patched

# %% [markdown]
# ## Create MLX training script
#
# We need to wrap our training script into a function to create Kubeflow TrainJob.
#
# This is the simple MLP model to recognize digits from the MNIST dataset.

# %%
def mlx_train_mnist(args):
    import time
    from functools import partial
    import mlx.core as mx
    import mlx.nn as nn
    import mlx.optimizers as optim
    from mlx.data.datasets import load_mnist
    import boto3

    # Define a simple MLP model with MLX.
    class MLP(nn.Module):
        def __init__(
            self, in_dims: int, hidden_dims: int, num_layers: int, out_dims: int
        ):
            super().__init__()
            layer_sizes = [in_dims] + [hidden_dims] * num_layers + [out_dims]
            self.layers = [
                nn.Linear(idim, odim)
                for idim, odim in zip(layer_sizes[:-1], layer_sizes[1:])
            ]

        def __call__(self, x):
            for layer in self.layers[:-1]:
                x = nn.relu(layer(x))
            return self.layers[-1](x)

    # Initializer MLX distributed backend.
    dist = mx.distributed.init(strict=True, backend="mpi")
    world_size = dist.size()
    rank = dist.rank()
    print(f"Start Distributed Training, WORLD_SIZE: {world_size}, RANK: {rank}")

    if rank == 0:
        print("Download MNIST dataset")

    # Load MNIST dataset and partition it.
    BATCH_SIZE = 128
    train_dataset = load_mnist()

    distributed_ds = (
        train_dataset.shuffle()
        .partition_if(world_size > 1, world_size, rank)
        .key_transform("image", lambda x: (x.astype("float32") / 255.0).ravel())
    )

    # Create the MLP model and SGD optimizer
    model = MLP(
        in_dims=distributed_ds[0]["image"].shape[-1],
        hidden_dims=32,
        num_layers=2,
        out_dims=10,
    )
    optimizer = optim.SGD(learning_rate=0.01)

    # Define function to calculate loss and accuracy.
    def loss_fn(model, x, y):
        output = model(x)
        loss = mx.mean(nn.losses.cross_entropy(output, y))
        acc = mx.mean(mx.argmax(output, axis=1) == y)
        return loss, acc

    # Define single training step.
    @partial(mx.compile, inputs=model.state, outputs=model.state)
    def step(x, y):
        loss_and_grad_fn = nn.value_and_grad(model, loss_fn)
        (loss, acc), grads = loss_and_grad_fn(model, x, y)
        # Average grads to aggregate them across distributed nodes.
        grads = nn.utils.average_gradients(grads)
        optimizer.update(model, grads)
        return loss, acc

    # Average statistic across distributed nodes.
    def average_stats(stats, count):
        with mx.stream(mx.cpu):
            stats = mx.distributed.all_sum(mx.array(stats))
            count = mx.distributed.all_sum(count)
            return (stats / count).tolist()

    # Start distributed training.
    if rank == 0:
        print("Start MLX training")
    for epoch in range(15):
        epoch_start = time.perf_counter()
        losses = accuracies = count = 0

        for batch_idx, batch_sample in enumerate(distributed_ds.batch(BATCH_SIZE)):
            x = mx.array(batch_sample["image"])
            y = mx.array(batch_sample["label"])
            loss, acc = step(x, y)
            mx.eval(loss, acc, model.state)

            losses += loss.item()
            accuracies += acc.item()
            count += 1

            # Print the results.
            if batch_idx % 10 == 0:
                loss, acc = average_stats([losses, accuracies], count)
                if rank == 0:
                    print(
                        "Epoch: {} [{}/{} ({:.0f}%)] \tTrain loss: {:.3f}, acc: {:.3f}".format(
                            epoch,
                            batch_idx * len(x),
                            len(train_dataset),
                            100.0 * batch_idx * len(x) / len(train_dataset),
                            loss,
                            acc,
                        )
                    )
        if rank == 0:
            print(
                "Epoch: {}, time: {:.2f} seconds\n\n".format(
                    epoch, time.perf_counter() - epoch_start
                )
            )

    # Finally, export model to S3.
    if rank == 0:
        print("Exporting MNIST model to S3")
        model.save_weights(args["MODEL"])
        boto3.client("s3").upload_file(args["MODEL"], args["BUCKET"], args["MODEL"])

# %% [markdown]
# ## Get the MLX Runtime
#
# You can list the available Kubeflow Trainer runtimes with the `list_runtimes()` API.
#
# The name of MLX runtime is `mlx-distributed`.

# %%
from kubeflow.trainer import TrainerClient, CustomTrainer

for r in TrainerClient().list_runtimes():
    if r.name == "mlx-distributed":
        print(f"Name: {r.name}, Framework: {r.trainer.framework}, Trainer Type: {r.trainer.trainer_type.value}\n")
        mlx_runtime = r
# Out:
# Name: mlx-distributed, Framework: mlx, Trainer Type: CustomTrainer

# %% [markdown]
# ## Create TrainJob for Distributed Training
#
# Use the `train()` API to create distributed TrainJob on **3 GPUs**. Every MPI training node uses 1 GPU.
#
# **Note:** Update the S3 bucket name.

# %%
# BUCKET = "Add your S3 bucket"
MODEL = "mnist.npz"

# %%
args = {"BUCKET": BUCKET, "MODEL": MODEL}

job_id = TrainerClient().train(
    trainer=CustomTrainer(
        func=mlx_train_mnist,
        func_args=args,
        num_nodes=3,
        packages_to_install=["boto3"],
    ),
    runtime=mlx_runtime,
)

# %%
# Train API generates a random TrainJob id.
job_id
# Out:
# 'ded466394d86'

# %% [markdown]
# ## Check the TrainJob Info
#
# Use the `list_jobs()` and `get_job()` APIs to get information about created TrainJob and its steps.

# %%
for job in TrainerClient().list_jobs():
    print(f"TrainJob: {job.name}, Status: {job.status}, Created at: {job.creation_timestamp}")
# Out:
# TrainJob: ded466394d86, Status: Created, Created at: 2025-08-18 12:40:28+00:00
# TrainJob: i7c9cd1d7392, Status: Complete, Created at: 2025-08-18 12:32:35+00:00

# %%
# We execute mpirun command on node-0, which functions as the MPI Launcher node.
for c in TrainerClient().get_job(name=job_id).steps:
    print(f"Step: {c.name}, Status: {c.status}, Devices: {c.device} x {c.device_count}\n")
# Out:
# Step: node-0, Status: Running, Devices: gpu x 1
#
# Step: node-1, Status: Running, Devices: gpu x 1
#
# Step: node-2, Status: Running, Devices: gpu x 1

# %% [markdown]
# ## Get the TrainJob Logs
#
# Use the `get_job_logs()` API to retrieve the TrainJob logs.
#
# Since we distribute the dataset across 3 GPUs, each rank processes `round(60,000 / 3) = 20,000` samples.

# %%
_ = TrainerClient().get_job_logs(name=job_id, follow=True)
# Out:
# [node-0]: Warning: Permanently added '[ded466394d86-node-0-0.ded466394d86]:2222' (ECDSA) to the list of known hosts.
# [node-0]: Warning: Permanently added '[ded466394d86-node-0-1.ded466394d86]:2222' (ECDSA) to the list of known hosts.
# [node-0]: Start Distributed Training, WORLD_SIZE: 3, RANK: 0
# [node-0]: Download MNIST dataset
# [node-0]: Start Distributed Training, WORLD_SIZE: 3, RANK: 1
# [node-0]: Start Distributed Training, WORLD_SIZE: 3, RANK: 2
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/train-images-idx3-ubyte.gz |█████████████████████████               | 5.9MiB / 9.5MiB (90.4MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/train-images-idx3-ubyte.gz |█████████████████████████████████████   | 8.8MiB / 9.5MiB (115.2MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/train-images-idx3-ubyte.gz 9.5MiB (121.0MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/t10k-images-idx3-ubyte.gz 1.6MiB (43.9MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/t10k-images-idx3-ubyte.gz |███████████████████████████████████████ | 1.5MiB / 1.6MiB (39.8MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/t10k-images-idx3-ubyte.gz 1.6MiB (40.6MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/train-labels-idx1-ubyte.gz 32.0KiB (18.6MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/train-labels-idx1-ubyte.gz 32.0KiB (12.4MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/train-labels-idx1-ubyte.gz 32.0KiB (11.6MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/t10k-labels-idx1-ubyte.gz 8.0KiB (57.8MiB/s)
# Downloading https://raw.githubusercontent.com/fgnt/mnist/master/t10k-labels-idx1-ubyte.gz 8.0KiB (60.7MiB/s)
# [node-0]:
# [node-0]: Start MLX training
# [node-0]: Epoch: 0 [0/60000 (0%)] 	Train loss: 2.304, acc: 0.091
# [node-0]: Epoch: 0 [1280/60000 (2%)] 	Train loss: 2.312, acc: 0.094
# [node-0]: Epoch: 0 [2560/60000 (4%)] 	Train loss: 2.310, acc: 0.100
# [node-0]: Epoch: 0 [3840/60000 (6%)] 	Train loss: 2.309, acc: 0.100
# [node-0]: Epoch: 0 [5120/60000 (9%)] 	Train loss: 2.308, acc: 0.100
# [node-0]: Epoch: 0 [6400/60000 (11%)] 	Train loss: 2.308, acc: 0.101
# [node-0]: Epoch: 0 [7680/60000 (13%)] 	Train loss: 2.308, acc: 0.100
# [node-0]: Epoch: 0 [8960/60000 (15%)] 	Train loss: 2.307, acc: 0.101
# [node-0]: Epoch: 0 [10240/60000 (17%)] 	Train loss: 2.307, acc: 0.100
# [node-0]: Epoch: 0 [11520/60000 (19%)] 	Train loss: 2.307, acc: 0.100
# [node-0]: Epoch: 0 [12800/60000 (21%)] 	Train loss: 2.306, acc: 0.100
# [node-0]: Epoch: 0 [14080/60000 (23%)] 	Train loss: 2.305, acc: 0.101
# [node-0]: Epoch: 0 [15360/60000 (26%)] 	Train loss: 2.305, acc: 0.102
# [node-0]: Epoch: 0 [16640/60000 (28%)] 	Train loss: 2.305, acc: 0.102
# [node-0]: Epoch: 0 [17920/60000 (30%)] 	Train loss: 2.304, acc: 0.103
# [node-0]: Epoch: 0 [19200/60000 (32%)] 	Train loss: 2.304, acc: 0.104
# [node-0]: Epoch: 0, time: 29.12 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 1 [0/60000 (0%)] 	Train loss: 2.289, acc: 0.125
# [node-0]: Epoch: 1 [1280/60000 (2%)] 	Train loss: 2.298, acc: 0.123
# [node-0]: Epoch: 1 [2560/60000 (4%)] 	Train loss: 2.295, acc: 0.131
# [node-0]: Epoch: 1 [3840/60000 (6%)] 	Train loss: 2.294, acc: 0.134
# [node-0]: Epoch: 1 [5120/60000 (9%)] 	Train loss: 2.294, acc: 0.136
# [node-0]: Epoch: 1 [6400/60000 (11%)] 	Train loss: 2.294, acc: 0.138
# [node-0]: Epoch: 1 [7680/60000 (13%)] 	Train loss: 2.294, acc: 0.140
# [node-0]: Epoch: 1 [8960/60000 (15%)] 	Train loss: 2.293, acc: 0.141
# [node-0]: Epoch: 1 [10240/60000 (17%)] 	Train loss: 2.293, acc: 0.142
# [node-0]: Epoch: 1 [11520/60000 (19%)] 	Train loss: 2.293, acc: 0.142
# [node-0]: Epoch: 1 [12800/60000 (21%)] 	Train loss: 2.292, acc: 0.144
# [node-0]: Epoch: 1 [14080/60000 (23%)] 	Train loss: 2.291, acc: 0.145
# [node-0]: Epoch: 1 [15360/60000 (26%)] 	Train loss: 2.291, acc: 0.147
# [node-0]: Epoch: 1 [16640/60000 (28%)] 	Train loss: 2.291, acc: 0.147
# [node-0]: Epoch: 1 [17920/60000 (30%)] 	Train loss: 2.290, acc: 0.148
# [node-0]: Epoch: 1 [19200/60000 (32%)] 	Train loss: 2.289, acc: 0.149
# [node-0]: Epoch: 1, time: 0.49 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 2 [0/60000 (0%)] 	Train loss: 2.274, acc: 0.161
# [node-0]: Epoch: 2 [1280/60000 (2%)] 	Train loss: 2.284, acc: 0.163
# [node-0]: Epoch: 2 [2560/60000 (4%)] 	Train loss: 2.281, acc: 0.166
# [node-0]: Epoch: 2 [3840/60000 (6%)] 	Train loss: 2.280, acc: 0.170
# [node-0]: Epoch: 2 [5120/60000 (9%)] 	Train loss: 2.279, acc: 0.171
# [node-0]: Epoch: 2 [6400/60000 (11%)] 	Train loss: 2.279, acc: 0.170
# [node-0]: Epoch: 2 [7680/60000 (13%)] 	Train loss: 2.278, acc: 0.172
# [node-0]: Epoch: 2 [8960/60000 (15%)] 	Train loss: 2.278, acc: 0.172
# [node-0]: Epoch: 2 [10240/60000 (17%)] 	Train loss: 2.277, acc: 0.174
# [node-0]: Epoch: 2 [11520/60000 (19%)] 	Train loss: 2.277, acc: 0.174
# [node-0]: Epoch: 2 [12800/60000 (21%)] 	Train loss: 2.276, acc: 0.175
# [node-0]: Epoch: 2 [14080/60000 (23%)] 	Train loss: 2.275, acc: 0.177
# [node-0]: Epoch: 2 [15360/60000 (26%)] 	Train loss: 2.275, acc: 0.178
# [node-0]: Epoch: 2 [16640/60000 (28%)] 	Train loss: 2.274, acc: 0.179
# [node-0]: Epoch: 2 [17920/60000 (30%)] 	Train loss: 2.273, acc: 0.181
# [node-0]: Epoch: 2 [19200/60000 (32%)] 	Train loss: 2.272, acc: 0.182
# [node-0]: Epoch: 2, time: 0.49 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 3 [0/60000 (0%)] 	Train loss: 2.254, acc: 0.203
# [node-0]: Epoch: 3 [1280/60000 (2%)] 	Train loss: 2.264, acc: 0.198
# [node-0]: Epoch: 3 [2560/60000 (4%)] 	Train loss: 2.262, acc: 0.203
# [node-0]: Epoch: 3 [3840/60000 (6%)] 	Train loss: 2.259, acc: 0.209
# [node-0]: Epoch: 3 [5120/60000 (9%)] 	Train loss: 2.258, acc: 0.211
# [node-0]: Epoch: 3 [6400/60000 (11%)] 	Train loss: 2.257, acc: 0.212
# [node-0]: Epoch: 3 [7680/60000 (13%)] 	Train loss: 2.256, acc: 0.213
# [node-0]: Epoch: 3 [8960/60000 (15%)] 	Train loss: 2.256, acc: 0.214
# [node-0]: Epoch: 3 [10240/60000 (17%)] 	Train loss: 2.255, acc: 0.216
# [node-0]: Epoch: 3 [11520/60000 (19%)] 	Train loss: 2.254, acc: 0.218
# [node-0]: Epoch: 3 [12800/60000 (21%)] 	Train loss: 2.253, acc: 0.220
# [node-0]: Epoch: 3 [14080/60000 (23%)] 	Train loss: 2.251, acc: 0.222
# [node-0]: Epoch: 3 [15360/60000 (26%)] 	Train loss: 2.250, acc: 0.224
# [node-0]: Epoch: 3 [16640/60000 (28%)] 	Train loss: 2.250, acc: 0.224
# [node-0]: Epoch: 3 [17920/60000 (30%)] 	Train loss: 2.248, acc: 0.226
# [node-0]: Epoch: 3 [19200/60000 (32%)] 	Train loss: 2.247, acc: 0.227
# [node-0]: Epoch: 3, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 4 [0/60000 (0%)] 	Train loss: 2.223, acc: 0.237
# [node-0]: Epoch: 4 [1280/60000 (2%)] 	Train loss: 2.233, acc: 0.234
# [node-0]: Epoch: 4 [2560/60000 (4%)] 	Train loss: 2.230, acc: 0.240
# [node-0]: Epoch: 4 [3840/60000 (6%)] 	Train loss: 2.226, acc: 0.247
# [node-0]: Epoch: 4 [5120/60000 (9%)] 	Train loss: 2.224, acc: 0.249
# [node-0]: Epoch: 4 [6400/60000 (11%)] 	Train loss: 2.223, acc: 0.252
# [node-0]: Epoch: 4 [7680/60000 (13%)] 	Train loss: 2.221, acc: 0.254
# [node-0]: Epoch: 4 [8960/60000 (15%)] 	Train loss: 2.220, acc: 0.256
# [node-0]: Epoch: 4 [10240/60000 (17%)] 	Train loss: 2.218, acc: 0.260
# [node-0]: Epoch: 4 [11520/60000 (19%)] 	Train loss: 2.216, acc: 0.261
# [node-0]: Epoch: 4 [12800/60000 (21%)] 	Train loss: 2.214, acc: 0.265
# [node-0]: Epoch: 4 [14080/60000 (23%)] 	Train loss: 2.212, acc: 0.267
# [node-0]: Epoch: 4 [15360/60000 (26%)] 	Train loss: 2.210, acc: 0.270
# [node-0]: Epoch: 4 [16640/60000 (28%)] 	Train loss: 2.209, acc: 0.271
# [node-0]: Epoch: 4 [17920/60000 (30%)] 	Train loss: 2.207, acc: 0.273
# [node-0]: Epoch: 4 [19200/60000 (32%)] 	Train loss: 2.205, acc: 0.274
# [node-0]: Epoch: 4, time: 0.49 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 5 [0/60000 (0%)] 	Train loss: 2.167, acc: 0.279
# [node-0]: Epoch: 5 [1280/60000 (2%)] 	Train loss: 2.178, acc: 0.277
# [node-0]: Epoch: 5 [2560/60000 (4%)] 	Train loss: 2.174, acc: 0.281
# [node-0]: Epoch: 5 [3840/60000 (6%)] 	Train loss: 2.167, acc: 0.290
# [node-0]: Epoch: 5 [5120/60000 (9%)] 	Train loss: 2.165, acc: 0.289
# [node-0]: Epoch: 5 [6400/60000 (11%)] 	Train loss: 2.161, acc: 0.292
# [node-0]: Epoch: 5 [7680/60000 (13%)] 	Train loss: 2.158, acc: 0.294
# [node-0]: Epoch: 5 [8960/60000 (15%)] 	Train loss: 2.155, acc: 0.294
# [node-0]: Epoch: 5 [10240/60000 (17%)] 	Train loss: 2.152, acc: 0.295
# [node-0]: Epoch: 5 [11520/60000 (19%)] 	Train loss: 2.149, acc: 0.295
# [node-0]: Epoch: 5 [12800/60000 (21%)] 	Train loss: 2.146, acc: 0.297
# [node-0]: Epoch: 5 [14080/60000 (23%)] 	Train loss: 2.142, acc: 0.298
# [node-0]: Epoch: 5 [15360/60000 (26%)] 	Train loss: 2.139, acc: 0.299
# [node-0]: Epoch: 5 [16640/60000 (28%)] 	Train loss: 2.136, acc: 0.299
# [node-0]: Epoch: 5 [17920/60000 (30%)] 	Train loss: 2.132, acc: 0.300
# [node-0]: Epoch: 5 [19200/60000 (32%)] 	Train loss: 2.128, acc: 0.301
# [node-0]: Epoch: 5, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 6 [0/60000 (0%)] 	Train loss: 2.067, acc: 0.286
# [node-0]: Epoch: 6 [1280/60000 (2%)] 	Train loss: 2.077, acc: 0.300
# [node-0]: Epoch: 6 [2560/60000 (4%)] 	Train loss: 2.071, acc: 0.307
# [node-0]: Epoch: 6 [3840/60000 (6%)] 	Train loss: 2.059, acc: 0.318
# [node-0]: Epoch: 6 [5120/60000 (9%)] 	Train loss: 2.055, acc: 0.316
# [node-0]: Epoch: 6 [6400/60000 (11%)] 	Train loss: 2.049, acc: 0.321
# [node-0]: Epoch: 6 [7680/60000 (13%)] 	Train loss: 2.043, acc: 0.323
# [node-0]: Epoch: 6 [8960/60000 (15%)] 	Train loss: 2.039, acc: 0.322
# [node-0]: Epoch: 6 [10240/60000 (17%)] 	Train loss: 2.034, acc: 0.323
# [node-0]: Epoch: 6 [11520/60000 (19%)] 	Train loss: 2.029, acc: 0.324
# [node-0]: Epoch: 6 [12800/60000 (21%)] 	Train loss: 2.024, acc: 0.326
# [node-0]: Epoch: 6 [14080/60000 (23%)] 	Train loss: 2.018, acc: 0.327
# [node-0]: Epoch: 6 [15360/60000 (26%)] 	Train loss: 2.012, acc: 0.329
# [node-0]: Epoch: 6 [16640/60000 (28%)] 	Train loss: 2.007, acc: 0.330
# [node-0]: Epoch: 6 [17920/60000 (30%)] 	Train loss: 2.002, acc: 0.332
# [node-0]: Epoch: 6 [19200/60000 (32%)] 	Train loss: 1.996, acc: 0.334
# [node-0]: Epoch: 6, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 7 [0/60000 (0%)] 	Train loss: 1.907, acc: 0.328
# [node-0]: Epoch: 7 [1280/60000 (2%)] 	Train loss: 1.913, acc: 0.352
# [node-0]: Epoch: 7 [2560/60000 (4%)] 	Train loss: 1.906, acc: 0.362
# [node-0]: Epoch: 7 [3840/60000 (6%)] 	Train loss: 1.888, acc: 0.376
# [node-0]: Epoch: 7 [5120/60000 (9%)] 	Train loss: 1.883, acc: 0.377
# [node-0]: Epoch: 7 [6400/60000 (11%)] 	Train loss: 1.874, acc: 0.384
# [node-0]: Epoch: 7 [7680/60000 (13%)] 	Train loss: 1.866, acc: 0.388
# [node-0]: Epoch: 7 [8960/60000 (15%)] 	Train loss: 1.860, acc: 0.390
# [node-0]: Epoch: 7 [10240/60000 (17%)] 	Train loss: 1.852, acc: 0.395
# [node-0]: Epoch: 7 [11520/60000 (19%)] 	Train loss: 1.845, acc: 0.398
# [node-0]: Epoch: 7 [12800/60000 (21%)] 	Train loss: 1.838, acc: 0.402
# [node-0]: Epoch: 7 [14080/60000 (23%)] 	Train loss: 1.830, acc: 0.407
# [node-0]: Epoch: 7 [15360/60000 (26%)] 	Train loss: 1.821, acc: 0.411
# [node-0]: Epoch: 7 [16640/60000 (28%)] 	Train loss: 1.814, acc: 0.415
# [node-0]: Epoch: 7 [17920/60000 (30%)] 	Train loss: 1.806, acc: 0.418
# [node-0]: Epoch: 7 [19200/60000 (32%)] 	Train loss: 1.798, acc: 0.422
# [node-0]: Epoch: 7, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 8 [0/60000 (0%)] 	Train loss: 1.678, acc: 0.458
# [node-0]: Epoch: 8 [1280/60000 (2%)] 	Train loss: 1.677, acc: 0.479
# [node-0]: Epoch: 8 [2560/60000 (4%)] 	Train loss: 1.668, acc: 0.481
# [node-0]: Epoch: 8 [3840/60000 (6%)] 	Train loss: 1.647, acc: 0.490
# [node-0]: Epoch: 8 [5120/60000 (9%)] 	Train loss: 1.640, acc: 0.490
# [node-0]: Epoch: 8 [6400/60000 (11%)] 	Train loss: 1.628, acc: 0.496
# [node-0]: Epoch: 8 [7680/60000 (13%)] 	Train loss: 1.618, acc: 0.499
# [node-0]: Epoch: 8 [8960/60000 (15%)] 	Train loss: 1.611, acc: 0.501
# [node-0]: Epoch: 8 [10240/60000 (17%)] 	Train loss: 1.601, acc: 0.505
# [node-0]: Epoch: 8 [11520/60000 (19%)] 	Train loss: 1.591, acc: 0.509
# [node-0]: Epoch: 8 [12800/60000 (21%)] 	Train loss: 1.582, acc: 0.513
# [node-0]: Epoch: 8 [14080/60000 (23%)] 	Train loss: 1.571, acc: 0.517
# [node-0]: Epoch: 8 [15360/60000 (26%)] 	Train loss: 1.560, acc: 0.521
# [node-0]: Epoch: 8 [16640/60000 (28%)] 	Train loss: 1.551, acc: 0.524
# [node-0]: Epoch: 8 [17920/60000 (30%)] 	Train loss: 1.542, acc: 0.527
# [node-0]: Epoch: 8 [19200/60000 (32%)] 	Train loss: 1.533, acc: 0.531
# [node-0]: Epoch: 8, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 9 [0/60000 (0%)] 	Train loss: 1.390, acc: 0.570
# [node-0]: Epoch: 9 [1280/60000 (2%)] 	Train loss: 1.387, acc: 0.572
# [node-0]: Epoch: 9 [2560/60000 (4%)] 	Train loss: 1.380, acc: 0.573
# [node-0]: Epoch: 9 [3840/60000 (6%)] 	Train loss: 1.360, acc: 0.581
# [node-0]: Epoch: 9 [5120/60000 (9%)] 	Train loss: 1.355, acc: 0.581
# [node-0]: Epoch: 9 [6400/60000 (11%)] 	Train loss: 1.343, acc: 0.585
# [node-0]: Epoch: 9 [7680/60000 (13%)] 	Train loss: 1.335, acc: 0.587
# [node-0]: Epoch: 9 [8960/60000 (15%)] 	Train loss: 1.329, acc: 0.589
# [node-0]: Epoch: 9 [10240/60000 (17%)] 	Train loss: 1.320, acc: 0.592
# [node-0]: Epoch: 9 [11520/60000 (19%)] 	Train loss: 1.311, acc: 0.594
# [node-0]: Epoch: 9 [12800/60000 (21%)] 	Train loss: 1.303, acc: 0.597
# [node-0]: Epoch: 9 [14080/60000 (23%)] 	Train loss: 1.294, acc: 0.601
# [node-0]: Epoch: 9 [15360/60000 (26%)] 	Train loss: 1.285, acc: 0.603
# [node-0]: Epoch: 9 [16640/60000 (28%)] 	Train loss: 1.277, acc: 0.606
# [node-0]: Epoch: 9 [17920/60000 (30%)] 	Train loss: 1.270, acc: 0.609
# [node-0]: Epoch: 9 [19200/60000 (32%)] 	Train loss: 1.262, acc: 0.612
# [node-0]: Epoch: 9, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 10 [0/60000 (0%)] 	Train loss: 1.150, acc: 0.633
# [node-0]: Epoch: 10 [1280/60000 (2%)] 	Train loss: 1.150, acc: 0.636
# [node-0]: Epoch: 10 [2560/60000 (4%)] 	Train loss: 1.148, acc: 0.643
# [node-0]: Epoch: 10 [3840/60000 (6%)] 	Train loss: 1.133, acc: 0.650
# [node-0]: Epoch: 10 [5120/60000 (9%)] 	Train loss: 1.130, acc: 0.651
# [node-0]: Epoch: 10 [6400/60000 (11%)] 	Train loss: 1.121, acc: 0.656
# [node-0]: Epoch: 10 [7680/60000 (13%)] 	Train loss: 1.116, acc: 0.658
# [node-0]: Epoch: 10 [8960/60000 (15%)] 	Train loss: 1.113, acc: 0.659
# [node-0]: Epoch: 10 [10240/60000 (17%)] 	Train loss: 1.106, acc: 0.661
# [node-0]: Epoch: 10 [11520/60000 (19%)] 	Train loss: 1.100, acc: 0.663
# [node-0]: Epoch: 10 [12800/60000 (21%)] 	Train loss: 1.095, acc: 0.665
# [node-0]: Epoch: 10 [14080/60000 (23%)] 	Train loss: 1.088, acc: 0.668
# [node-0]: Epoch: 10 [15360/60000 (26%)] 	Train loss: 1.082, acc: 0.670
# [node-0]: Epoch: 10 [16640/60000 (28%)] 	Train loss: 1.077, acc: 0.671
# [node-0]: Epoch: 10 [17920/60000 (30%)] 	Train loss: 1.072, acc: 0.673
# [node-0]: Epoch: 10 [19200/60000 (32%)] 	Train loss: 1.067, acc: 0.675
# [node-0]: Epoch: 10, time: 0.49 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 11 [0/60000 (0%)] 	Train loss: 0.992, acc: 0.714
# [node-0]: Epoch: 11 [1280/60000 (2%)] 	Train loss: 0.994, acc: 0.694
# [node-0]: Epoch: 11 [2560/60000 (4%)] 	Train loss: 0.996, acc: 0.693
# [node-0]: Epoch: 11 [3840/60000 (6%)] 	Train loss: 0.983, acc: 0.698
# [node-0]: Epoch: 11 [5120/60000 (9%)] 	Train loss: 0.982, acc: 0.698
# [node-0]: Epoch: 11 [6400/60000 (11%)] 	Train loss: 0.975, acc: 0.703
# [node-0]: Epoch: 11 [7680/60000 (13%)] 	Train loss: 0.973, acc: 0.704
# [node-0]: Epoch: 11 [8960/60000 (15%)] 	Train loss: 0.972, acc: 0.703
# [node-0]: Epoch: 11 [10240/60000 (17%)] 	Train loss: 0.967, acc: 0.703
# [node-0]: Epoch: 11 [11520/60000 (19%)] 	Train loss: 0.962, acc: 0.705
# [node-0]: Epoch: 11 [12800/60000 (21%)] 	Train loss: 0.959, acc: 0.706
# [node-0]: Epoch: 11 [14080/60000 (23%)] 	Train loss: 0.953, acc: 0.707
# [node-0]: Epoch: 11 [15360/60000 (26%)] 	Train loss: 0.949, acc: 0.709
# [node-0]: Epoch: 11 [16640/60000 (28%)] 	Train loss: 0.945, acc: 0.710
# [node-0]: Epoch: 11 [17920/60000 (30%)] 	Train loss: 0.942, acc: 0.712
# [node-0]: Epoch: 11 [19200/60000 (32%)] 	Train loss: 0.938, acc: 0.713
# [node-0]: Epoch: 11, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 12 [0/60000 (0%)] 	Train loss: 0.885, acc: 0.734
# [node-0]: Epoch: 12 [1280/60000 (2%)] 	Train loss: 0.888, acc: 0.726
# [node-0]: Epoch: 12 [2560/60000 (4%)] 	Train loss: 0.891, acc: 0.724
# [node-0]: Epoch: 12 [3840/60000 (6%)] 	Train loss: 0.881, acc: 0.728
# [node-0]: Epoch: 12 [5120/60000 (9%)] 	Train loss: 0.880, acc: 0.728
# [node-0]: Epoch: 12 [6400/60000 (11%)] 	Train loss: 0.874, acc: 0.732
# [node-0]: Epoch: 12 [7680/60000 (13%)] 	Train loss: 0.873, acc: 0.732
# [node-0]: Epoch: 12 [8960/60000 (15%)] 	Train loss: 0.873, acc: 0.730
# [node-0]: Epoch: 12 [10240/60000 (17%)] 	Train loss: 0.869, acc: 0.731
# [node-0]: Epoch: 12 [11520/60000 (19%)] 	Train loss: 0.865, acc: 0.732
# [node-0]: Epoch: 12 [12800/60000 (21%)] 	Train loss: 0.863, acc: 0.733
# [node-0]: Epoch: 12 [14080/60000 (23%)] 	Train loss: 0.858, acc: 0.734
# [node-0]: Epoch: 12 [15360/60000 (26%)] 	Train loss: 0.854, acc: 0.735
# [node-0]: Epoch: 12 [16640/60000 (28%)] 	Train loss: 0.851, acc: 0.736
# [node-0]: Epoch: 12 [17920/60000 (30%)] 	Train loss: 0.849, acc: 0.738
# [node-0]: Epoch: 12 [19200/60000 (32%)] 	Train loss: 0.846, acc: 0.738
# [node-0]: Epoch: 12, time: 0.52 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 13 [0/60000 (0%)] 	Train loss: 0.806, acc: 0.747
# [node-0]: Epoch: 13 [1280/60000 (2%)] 	Train loss: 0.807, acc: 0.749
# [node-0]: Epoch: 13 [2560/60000 (4%)] 	Train loss: 0.812, acc: 0.749
# [node-0]: Epoch: 13 [3840/60000 (6%)] 	Train loss: 0.802, acc: 0.753
# [node-0]: Epoch: 13 [5120/60000 (9%)] 	Train loss: 0.803, acc: 0.753
# [node-0]: Epoch: 13 [6400/60000 (11%)] 	Train loss: 0.797, acc: 0.756
# [node-0]: Epoch: 13 [7680/60000 (13%)] 	Train loss: 0.796, acc: 0.756
# [node-0]: Epoch: 13 [8960/60000 (15%)] 	Train loss: 0.797, acc: 0.754
# [node-0]: Epoch: 13 [10240/60000 (17%)] 	Train loss: 0.794, acc: 0.755
# [node-0]: Epoch: 13 [11520/60000 (19%)] 	Train loss: 0.790, acc: 0.757
# [node-0]: Epoch: 13 [12800/60000 (21%)] 	Train loss: 0.788, acc: 0.757
# [node-0]: Epoch: 13 [14080/60000 (23%)] 	Train loss: 0.784, acc: 0.758
# [node-0]: Epoch: 13 [15360/60000 (26%)] 	Train loss: 0.781, acc: 0.759
# [node-0]: Epoch: 13 [16640/60000 (28%)] 	Train loss: 0.778, acc: 0.760
# [node-0]: Epoch: 13 [17920/60000 (30%)] 	Train loss: 0.776, acc: 0.761
# [node-0]: Epoch: 13 [19200/60000 (32%)] 	Train loss: 0.774, acc: 0.762
# [node-0]: Epoch: 13, time: 0.49 seconds
# [node-0]:
# [node-0]:
# [node-0]: Epoch: 14 [0/60000 (0%)] 	Train loss: 0.743, acc: 0.776
# [node-0]: Epoch: 14 [1280/60000 (2%)] 	Train loss: 0.742, acc: 0.773
# [node-0]: Epoch: 14 [2560/60000 (4%)] 	Train loss: 0.746, acc: 0.771
# [node-0]: Epoch: 14 [3840/60000 (6%)] 	Train loss: 0.738, acc: 0.774
# [node-0]: Epoch: 14 [5120/60000 (9%)] 	Train loss: 0.739, acc: 0.774
# [node-0]: Epoch: 14 [6400/60000 (11%)] 	Train loss: 0.733, acc: 0.777
# [node-0]: Epoch: 14 [7680/60000 (13%)] 	Train loss: 0.733, acc: 0.777
# [node-0]: Epoch: 14 [8960/60000 (15%)] 	Train loss: 0.735, acc: 0.776
# [node-0]: Epoch: 14 [10240/60000 (17%)] 	Train loss: 0.732, acc: 0.776
# [node-0]: Epoch: 14 [11520/60000 (19%)] 	Train loss: 0.728, acc: 0.778
# [node-0]: Epoch: 14 [12800/60000 (21%)] 	Train loss: 0.727, acc: 0.779
# [node-0]: Epoch: 14 [14080/60000 (23%)] 	Train loss: 0.722, acc: 0.780
# [node-0]: Epoch: 14 [15360/60000 (26%)] 	Train loss: 0.720, acc: 0.781
# [node-0]: Epoch: 14 [16640/60000 (28%)] 	Train loss: 0.718, acc: 0.782
# [node-0]: Epoch: 14 [17920/60000 (30%)] 	Train loss: 0.715, acc: 0.783
# [node-0]: Epoch: 14 [19200/60000 (32%)] 	Train loss: 0.714, acc: 0.784
# [node-0]: Epoch: 14, time: 0.50 seconds
# [node-0]:
# [node-0]:
# [node-0]: Exporting MNIST model to S3

# %% [markdown]
# ## Evaluate the Trained Model
#
# Download the trained model from S3 to evaluate it.
#
# We will use test images from the MNIST dataset for prediction.
#
# - <span style="color:green">Green label</span> indicate correct predictions.
# - <span style="color:red">Red label</span> indicate incorrect predictions, with the correct value shown in parentheses.

# %%
import boto3

boto3.client("s3").download_file(BUCKET, MODEL, MODEL)

# %%
import mlx.core as mx
import mlx.nn as nn
import matplotlib.pyplot as plt
from mlx.data.datasets import load_mnist


# Load test dataset and take the random batch from it.
test_batch = (
    load_mnist(train=False)
    .key_transform("image", lambda x: (x.astype("float32") / 255.0).ravel())
    .batch(20)[mx.random.randint(10, 500)]
)

class MLP(nn.Module):
    def __init__(self, in_dims: int, hidden_dims: int, num_layers: int, out_dims: int):
        super().__init__()
        layer_sizes = [in_dims] + [hidden_dims] * num_layers + [out_dims]
        self.layers = [
            nn.Linear(idim, odim)
            for idim, odim in zip(layer_sizes[:-1], layer_sizes[1:])
        ]

    def __call__(self, x):
        for layer in self.layers[:-1]:
            x = nn.relu(layer(x))
        return self.layers[-1](x)

# Load weights from the trained model.
model = MLP(
    in_dims=test_batch["image"][0].shape[-1],
    hidden_dims=32,
    num_layers=2,
    out_dims=10,
).load_weights(MODEL)

# Send test batch to the pre-trained MLP model.
x = mx.array(test_batch["image"])
output = model(x)
fig = plt.figure(figsize=(15, 5))
for i in range(20):
    # Format the input image and the model output.
    image = test_batch["image"][i].reshape((28, 28))
    pred_label = mx.argmax(output[i])

    # Add data to the plot.
    ax = fig.add_subplot(4, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(image, cmap="gray")
    if test_batch["label"][i] == pred_label:
        ax.set_title(test_batch["label"][i], color="green")
    else:
        ax.set_title("{} ({})".format(pred_label, test_batch["label"][i]), color="red")

    ax.title.set_fontsize(20)
    fig.tight_layout()

# %% [markdown]
# ## Delete the TrainJob
#
# When TrainJob is finished, you can delete the resource.

# %%
TrainerClient().delete_job(job_id)
